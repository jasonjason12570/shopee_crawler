# %%
from selenium import webdriver
from bs4 import BeautifulSoup as soup
import time
from datetime import datetime
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException   
chrome_options = Options()
chrome_options.add_argument('--user-agent=Mozilla/5.0 (iPhone; CPU iPhone OS 10_3 like Mac OS X) AppleWebKit/602.1.50 (KHTML, like Gecko) CriOS/56.0.2924.75 Mobile/14E5239e Safari/602.1')
#driver = webdriver.Chrome('../chromedriver',options=chrome_options)
driver = webdriver.Chrome(ChromeDriverManager().install(),options=chrome_options)
driver.get('https://shopee.tw/%E9%9B%BB%E8%85%A6%E9%9B%B6%E7%B5%84%E4%BB%B6-cat.11041390.11041525?filters=9&page=0&sortBy=ctime')
import time
# -*- coding: utf-8 -*-
from time import sleep
from tqdm import tqdm, trange
import pandas as pd
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/hod00002778/.wdm/drivers/chromedriver/mac64/98.0.4758.102/chromedriver] found in cache
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/527834239.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(),options=chrome_options)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as soup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import argparse
import os

# %%
import sqlite3
db = sqlite3.connect('data.db')
cursor = db.cursor()
print('Connect ok')
# Out:
# Connect ok

# %%
def db_create():
# Create table
    cursor.execute(
    '''CREATE TABLE SHOPEE
    (ID INTEGER PRIMARY KEY AUTOINCREMENT,
    NAME TEXT NOT NULL,
    LINK TEXT NOT NULL,
    PRICE INT NOT NULL,
    DATE DATETIME NOT NULL);''')

    print('Table created.')
    db.commit()

# %%
def db_select(SQL):
    # Select table
    cursor.execute(SQL)
    print('Table select '+SQL)
    db.commit()

# %%
def db_update(SQL):
    # Update table
    cursor.execute(SQL)
    print('Table update '+SQL)
    db.commit()

# %%
def db_shopee(dic):
    # Update table
    
    cursor.execute(SQL)
    print('Table update '+SQL)
    db.commit()

# %%
def check_default_url():
    url = driver.current_url
    if(url =="https://shopee.tw/%E9%9B%BB%E8%85%A6%E9%9B%B6%E7%B5%84%E4%BB%B6-cat.11041390.11041525?filters=9&page=0&sortBy=ctime"):
        #print("check_default true")
        return True
    else:
        #print("not the same")
        #print(url)
        return False

# %%
def default_frame():
    while(not check_default_url()):
        driver.get('https://shopee.tw/%E9%9B%BB%E8%85%A6%E9%9B%B6%E7%B5%84%E4%BB%B6-cat.11041390.11041525?filters=9&page=0&sortBy=ctime')
        driver.switch_to.default_content()
        driver.switch_to.parent_frame()
        driver.implicitly_wait(5)
        time.sleep(0.5)
        if(check_default_url()):
            #print("default_frame ok")
            return True
            break
        print("default_frame not ok")
        return False
    return True

# %%
SCROLL_PAUSE_TIME = 0.5
def check_target_num(num):
    js = "window.scrollTo(0, document.body.scrollHeight);"
    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    while(True):
        for j in range (1,(int(num/10))):
            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            # Wait to load page
            time.sleep(SCROLL_PAUSE_TIME)
            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        driver.implicitly_wait(1)
        
        target = len(driver.find_elements_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div/div/div[2]/div[%s]"%(i)))
        if(target!=0):
            print("===========getTarget==========="+str(num))
            return True
            break
        else:
            print(target)
            print("get target loading")

# %%
def target_frame(num):
    while(check_default_url()):
        #print(driver.current_url)
        print(check_target_num(num))
        try:
            driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div/div/div[2]/div[%s]"%(num)).click()
        except:
            driver.refresh()
            driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div/div/div[2]/div[%s]"%(num)).click()
            
        driver.switch_to.default_content()
        driver.switch_to.parent_frame()
        driver.implicitly_wait(5)
        time.sleep(0.5)
        if(not check_default_url()):
            #print("target_frame ok")
            return True
            break
        print("target_frame not ok")
    return True

# %%
def get_data(url):
    
     while(True):
        driver.get(url)
        driver.implicitly_wait(5)
        currrent = (driver.current_url)
        time.sleep(0.5)
        data=len(driver.find_elements_by_css_selector("._2KfNaM"))
        if(url == currrent):
            if(data>0):
                #data=driver.find_element_by_css_selector("._2KfNaM").text
                #print(data)
                try:
                    data=driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div/div[2]/div[3]/div[7]/div/div[1]/div[2]/span').text
                except:
                    data=driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div/div[2]/div[3]/div[8]/div/div[1]/div[2]/span').text
                print(data)
                return data
                break
            else:
                driver.refresh()
                data=len(driver.find_elements_by_css_selector("._2KfNaM"))
                if(data>0):
                    try:
                        data=driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div/div[2]/div[3]/div[7]/div/div[1]/div[2]/span').text
                    except:
                        data=driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div/div[2]/div[3]/div[8]/div/div[1]/div[2]/span').text
                    print(data)
                    return data
                    break

# %%
def get_all_links(num):
    driver.get('https://shopee.tw/%E9%9B%BB%E8%85%A6%E9%9B%B6%E7%B5%84%E4%BB%B6-cat.11041390.11041525?filters=9&page=0&sortBy=ctime')
    driver.implicitly_wait(5)
    d_tmp={}
    i = 1
    time_1 = time.time()
    js="document.documentElement.scrollTop=100000"
    #progress = tqdm(total=num)
    while(True):
        if(i > num):
            print("end")
            break
        for link in driver.find_elements_by_xpath('//*[@id="app"]/div/div[1]/div[2]/div/div/div[2]/div[%s]/a'%(i)):
            js='window.scrollBy(0,200)'
            driver.execute_script(js)
            time.sleep(0.1)
            name=(driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div[2]/div/div/div[2]/div[%s]/a/div/div/div[2]/div[1]/div/div'%(i)).text)
            price=(driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[2]/div/div/div[2]/div[%s]/a/div/div/div[2]/div[2]/div/span[2]'%(i)).text)
            link=(link.get_attribute('href'))
            try:
                time.sleep(0.1)
                d_tmp[link]=list()
                d_tmp[link].append(name)
                d_tmp[link].append(price)
                #d_tmp[link].append(link)
                #print(d_tmp[link])
                #print(i)
                i+=1
            except:
                print("error: "+str(num))
            
        
        #progress.update(1) 
    time_2 = time.time()
    time_interval = time_2 - time_1
    print(time_interval)
    return d_tmp

# %%
#check_target_num(100)

d = get_all_links(50)
# Out:
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/3232485560.py:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for link in driver.find_elements_by_xpath('//*[@id="app"]/div/div[1]/div[2]/div/div/div[2]/div[%s]/a'%(i)):
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/3232485560.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name=(driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div[2]/div/div/div[2]/div[%s]/a/div/div/div[2]/div[1]/div/div'%(i)).text)
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/3232485560.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price=(driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[2]/div/div/div[2]/div[%s]/a/div/div/div[2]/div[2]/div/span[2]'%(i)).text)
# end
# 27.80290412902832

# %%
from datetime import datetime
nowTime = int(time.time()) # 取得現在時間
dt_object = datetime.fromtimestamp(nowTime)

print("dt_object =", dt_object)
print("type(dt_object) =", type(dt_object))
# Out:
# dt_object = 2022-02-20 15:16:07
# type(dt_object) = <class 'datetime.datetime'>

# %%
df = pd.DataFrame(columns=['Link', 'Name', 'Price', 'Datetime', 'Timestamp'])

print("======================================")
for key, value in d.items():
    #print(key, value)
    date = get_data(key)
    
    tmp_num = 0
    now_time = int(time.time())
    product_timestamp = 0 #timestamp
    product_datetime = 0 #datetime
    if "分鐘" in date:
        tmp_num = date.find('分鐘')
        product_timestamp = now_time - (int(date[0:tmp_num])*60)
        product_datetime = datetime.fromtimestamp(product_timestamp)
    elif "小時" in date:
        tmp_num = date.find('小時')
        product_timestamp = now_time - (int(date[0:tmp_num])*3600)
        product_datetime = datetime.fromtimestamp(product_timestamp)
    elif "天" in date:
        tmp_num = date.find('天')
        product_timestamp = now_time - (int(date[0:tmp_num])*3600*24)
        product_datetime = datetime.fromtimestamp(product_timestamp)
    elif "月" in date:
        tmp_num = date.find('個')
        product_timestamp = now_time - (int(date[0:tmp_num])*3600*24*30)
        product_datetime = datetime.fromtimestamp(product_timestamp)
    elif "年" in date:
        tmp_num = date.find('年')
        product_timestamp = now_time - (int(date[0:tmp_num])*3600*24*30*12)
        product_datetime = datetime.fromtimestamp(product_timestamp)
    else:
        print("new label")

    df=df.append({'Link' : key , 'Name' : value[0], 'Price' : value[1], 'Datetime' : product_datetime, 'Timestamp' : product_timestamp} , ignore_index=True)
    print('Link:'+key)
    print('Name: '+value[0])
    print('Price: '+value[1])
    print('Datetime: '+ str(product_datetime))
    print('Timestamp: '+ str(product_timestamp))
    print("======================================")
# Out:
# ======================================
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/4076050028.py:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   data=len(driver.find_elements_by_css_selector("._2KfNaM"))
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/4076050028.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   data=driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div/div[2]/div[3]/div[7]/div/div[1]/div[2]/span').text
# 23小時
# Link:https://shopee.tw/AMD-RYZEN-R5-2400G-CPU-%E6%8A%80%E5%98%89-B450M-GAMING-MATX-%E4%B8%BB%E6%A9%9F%E6%9D%BF-i.25817203.14154132155?sp_atk=23396324-c330-4783-818e-c69d7f12d710
# Name: AMD RYZEN R5 2400G CPU + 技嘉 B450M GAMING MATX 主機板
# Price: 3,800
# Datetime: 2022-02-19 16:16:12
# Timestamp: 1645258572
# ======================================
# 4天
# Link:https://shopee.tw/%E8%8F%AF%E7%A2%A9-STRIX-GTX750TI-OC-2GD-%E5%85%8D%E6%8F%92%E9%9B%BB-%E9%A1%AF%E7%A4%BA%E5%8D%A1-%E5%B7%B2%E6%9B%B4%E6%8F%9B%E6%95%A3%E7%86%B1%E8%86%8F-i.10516886.17703300135?sp_atk=dfc2aa08-9bdb-4c36-9e10-db8e8d84975d
# Name: 華碩 STRIX-GTX750TI-OC-2GD 免插電 顯示卡 已更換散熱膏
# Price: 2,500
# Datetime: 2022-02-16 15:16:14
# Timestamp: 1644995774
# ======================================
# 4天
# Link:https://shopee.tw/CPU-Intel-Core-i7-4770-%E4%B8%BB%E6%9D%BF-MSI-B85M-P33-V2-%E5%90%AB%E9%A2%A8%E6%89%87%E6%93%8B%E6%9D%BF%E6%95%A3%E7%86%B1%E9%AB%98%E5%B7%B2%E6%9B%B4%E6%8F%9B%E6%B8%85%E6%BD%94-i.10516886.16703318073?sp_atk=4b0851cc-1f74-4a41-b6df-b541d0b7a81a
# Name: CPU Intel Core i7 4770+主板 MSI B85M-P33 V2 含風扇擋板散熱高已更換清潔
# Price: 3,500
# Datetime: 2022-02-16 15:16:16
# Timestamp: 1644995776
# ======================================
# /var/folders/mj/bf1cjbbd1zgd30jnz9zsyc8h0000gn/T/ipykernel_6664/4076050028.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   data=driver.find_element_by_xpath('//*[@id="app"]/div/div[1]/div/div[2]/div[3]/div[8]/div/div[1]/div[2]/span').text
# 10天
# Link:https://shopee.tw/3600x-%EF%BC%8B-%E6%95%A3%E7%86%B1%E5%99%A8-i.9715463.10886534078?sp_atk=4ccaf9f6-a3c4-43a8-903a-127838c16257
# Name: 3600x ＋ 散熱器
# Price: 5,800
# Datetime: 2022-02-10 15:16:22
# 49  https://shopee.tw/GV-R577UD-1GD-%E5%90%8C%E7%B...
#
#                                                  Name    Price  \
# 0   AMD RYZEN R5 2400G CPU + 技嘉 B450M GAMING MATX 主機板    3,800
# 1             華碩 STRIX-GTX750TI-OC-2GD 免插電 顯示卡 已更換散熱膏    2,500
# 2   CPU Intel Core i7 4770+主板 MSI B85M-P33 V2 含風扇擋...    3,500
# 3                                         3600x ＋ 散熱器    5,800
# 4                             nVidia Quadro GV100 無挖礦  100,000
# 5                                 微星 二手 B350 tomahawk    1,280
# 6                     【Cooler Master】Master Liquid 92    1,190
# 7                                          一超值故障顯示卡專區       50
# 8                                  麗臺GTX560TI 1GD5顯示卡      750
# 9                                  I3 10100T 超值電腦主機賠售    8,800
# 10                                    電腦風扇一批共5個送風扇擴充器      600
# 11                   ASUS HD7770-DC-1GD5-V2 HD7770顯示卡      650
# 12   半套電腦 MSI Z97 主機板、I5 4690K CPU 1150處理器、16G威剛終保記憶體    3,800
# 13                           MSI 微星 R9 270X 4G 故障 顯示卡      800
# 14  Sapphire 藍寶石 R9 270X 2G 三風扇顯示卡 效能約GTX 1050 優於G...    2,500
# 15          免運 現貨GeForce RTX™ 2070 WINDFORCE 2X 8G 裸卡   21,999
# 16                                      Intel i3-2130      100
# 17         1/27 現貨 極新良品 Intel i7 6700 六代cpu 1151 個保七天    4,390
# 18            1/27 現貨 良品 Intel i7 860 四代cpu 1156 個保七天      600
# 19         1/27 現貨 極新良品 Intel i7 4790 四代cpu 1150 個保七天    2,300
# 20         1/27 現貨 極新良品 Intel i7 6700 六代cpu 1151 個保七天    4,390
# 21            1/27 現貨 良品 Intel i7 860 四代cpu 1156 個保七天      600
# 22         1/27 現貨 極新良品 Intel i7 4790 四代cpu 1150 個保七天    2,300
# 23         1/27 現貨 極新良品 Intel i7 4770 四代cpu 1150 個保七天    2,000
# 24          1/27 現貨 Intel i5 6600 六代cpu 1151 極新良品個保七天    2,300
# 25                                 海盜船LL140 風扇X2 含控制器    1,500
# 26                                    EVGA GTX 660 2G    2,000
# 27            EVGA 3060 XC 無鎖未鎖（3090、3080、3070ti 可參考）   22,000
# 28     微星 MSI 1650 SUPER VENTUS XS OC 卡況佳 保固內 盒裝完整 面交    7,999
# 29                                    ROG GTX 1070 8G    8,200
# 30              顯示卡GALAXY影馳Geforce GT740 2GD5 128-bit    1,000
# 31       Intel Core I5-2400 CPU+華碩P8H61-M LX主機板/附風扇檔板      850
# 32                             ASUS-A78M-A主機板/FM2+/良品      550
# 33                        ASUS-A88XM-E主機板/FM2+/附檔板/良品      500
# 34   Intel XEON E3-1230V3 3.30G (SR153)/1150腳位/良品/附風扇    1,450
# 35             INTEL CORE i7-4770/ 3.40G /1150 腳位 /良品    1,950
# 36  二手 技嘉 顯示卡 rx5500xt gaming oc 4g 售出後不接受退換貨，過年期間...    7,500
# 37                     AMD Ryzen 3800X 3.9Ghz 八核心 CPU    8,500
# 38  3060ti 顯示卡 七彩虹 iGame colorful 3060 3070 3080參考...   19,499
# 39  3070ti msi ventus 3x oc RTX 3070 ti 微星 3070 30...   26,499
